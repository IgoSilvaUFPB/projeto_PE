# %%
# importando as bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
import seaborn as sns

# %%
# importando os dados
df = pd.read_csv('pontos.csv', header=None)
df
# Out:
#        0      1      2  3
# 0      0  82.88  82.73  2
# 1      1  54.39   6.12  1
# 2      2  24.88  56.56  3
# 3      3  85.00  29.00  4
# 4      4  35.58  53.10  3
# ..   ...    ...    ... ..
# 295  295  93.19  80.41  2
# 296  296  49.02   3.72  1
# 297  297  25.52  58.22  3
# 298  298  70.04  30.05  4
# 299  299  25.85  61.36  3
#
# [300 rows x 4 columns]

# %%
# selecionando as colunas
df = df[[1, 2]]
df
# Out:
#          1      2
# 0    82.88  82.73
# 1    54.39   6.12
# 2    24.88  56.56
# 3    85.00  29.00
# 4    35.58  53.10
# ..     ...    ...
# 295  93.19  80.41
# 296  49.02   3.72
# 297  25.52  58.22
# 298  70.04  30.05
# 299  25.85  61.36
#
# [300 rows x 2 columns]

# %%
# executando o kmeans
kmeans = KMeans(n_clusters=5, init='random')
kmeans.fit(df)
# Out:
# KMeans(init='random', n_clusters=5)

# %%
# plotando o gráfico
sns.scatterplot(data=df, x=1, y=2, hue=kmeans.labels_)
# Out:
# <AxesSubplot:xlabel='1', ylabel='2'>
