# %%
# importando as bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
import seaborn as sns

# %%
# importando os dados
df = pd.read_csv('pontos.csv', header=None)
df
# Out:
#        0      1      2  3
# 0      0  21.53  25.71  2
# 1      1  11.26   4.23  2
# 2      2  51.81  95.71  0
# 3      3  74.93  26.09  3
# 4      4  66.71  69.24  4
# ..   ...    ...    ... ..
# 295  295  24.33  52.34  1
# 296  296  13.65  13.24  2
# 297  297  66.13  86.60  0
# 298  298  92.29  35.53  3
# 299  299  50.41  58.15  4
#
# [300 rows x 4 columns]

# %%
# selecionando as colunas
df = df[[1, 2]]
df
# Out:
#          1      2
# 0    21.53  25.71
# 1    11.26   4.23
# 2    51.81  95.71
# 3    74.93  26.09
# 4    66.71  69.24
# ..     ...    ...
# 295  24.33  52.34
# 296  13.65  13.24
# 297  66.13  86.60
# 298  92.29  35.53
# 299  50.41  58.15
#
# [300 rows x 2 columns]

# %%
# executando o kmeans
kmeans = KMeans(n_clusters=5, init='random')
kmeans.fit(df)
# Out:
# KMeans(init='random', n_clusters=5)

# %%
# plotando o gráfico
sns.scatterplot(data=df, x=1, y=2, hue=kmeans.labels_)
# Out:
# <AxesSubplot:xlabel='1', ylabel='2'>
