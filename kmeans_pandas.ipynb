# %%
# importando as bibliotecas
import pandas as pd
from sklearn.cluster import KMeans
import seaborn as sns

# %%
# importando os dados
df = pd.read_csv('pontos.csv', header=None)
df
# Out:
#        0      1       2  3
# 0      0  52.25   79.74  0
# 1      1  22.63    1.95  1
# 2      2  23.28   46.66  3
# 3      3  26.99  109.69  0
# 4      4  83.14   65.58  2
# ..   ...    ...     ... ..
# 295  295  34.18   99.77  0
# 296  296  24.31    2.99  1
# 297  297  36.37   41.28  3
# 298  298  34.49   96.65  0
# 299  299  91.05   81.43  2
#
# [300 rows x 4 columns]

# %%
# selecionando as colunas
df = df[[1, 2]]
df
# Out:
#          1       2
# 0    52.25   79.74
# 1    22.63    1.95
# 2    23.28   46.66
# 3    26.99  109.69
# 4    83.14   65.58
# ..     ...     ...
# 295  34.18   99.77
# 296  24.31    2.99
# 297  36.37   41.28
# 298  34.49   96.65
# 299  91.05   81.43
#
# [300 rows x 2 columns]

# %%
# executando o kmeans
kmeans = KMeans(n_clusters=4, init='random')
kmeans.fit(df)
# Out:
# KMeans(init='random', n_clusters=4)

# %%
# plotando o gráfico
sns.scatterplot(data=df, x=1, y=2, hue=kmeans.labels_)
# Out:
# <AxesSubplot:xlabel='1', ylabel='2'>
